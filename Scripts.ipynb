# %% [markdown]
# # Scripts Notebook

# %% [markdown]
# #### Import packages

# %%
import pandas as pd

# %% [markdown]
# #### Set file paths for input file "Lista Equivalentes" and output files "TCA" and "Equivalentes"

# %%
input_path = "Lista Equivalentes.xlsx"
output_path_tca = "TCA.json"
output_path_equivalentes_detalhe = "EquivalentesDetalhe.json"
output_path_equivalentes = "Equivalentes.json"
output_path_equivalentes_csv = "Equivalentes.csv"
output_path_equivalentes_resumo_csv = "EquivalentesResumo.csv"
output_path_equivalentes_detalhe_csv = "EquivalentesDetalhe.csv"

# %% [markdown]
# #### Import relevant sheets from workbook

# %% [markdown]
# TCA

# %%
df1 = pd.read_excel(input_path,engine='openpyxl',sheet_name='TCA',usecols='A:AV')
df1.head()
# Out:
#        Nome do alimento           Source Código INSA  \
# 0         Abacate, Hass             INSA         624
# 1               Abacaxi  Alimentos Extra          na
# 2  Abóbora cristalizada             INSA         625
# 3          Abóbora crua             INSA         579
# 4        Abrótea cozida             INSA         801
#
#                                             Nível 1   \
# 0              Frutos e produtos derivados de frutos
# 1                          Fruta e produtos da fruta
# 2                    Produtos hortícolas e derivados
# 3                    Produtos hortícolas e derivados
# 4  Peixes, mariscos, anfíbios, répteis e inverteb...
#
#                                              Nível 2  \
# 0                         Fruta utilizada como fruta
# 1                                                NaN
# 2  Produtos hortícolas transformados ou em conser...
# 3                               Frutos de hortícolas
# 4                                    Peixe (músculo)
#
#                                             Nível 3   Energia (kcal)   \
# 0  Frutos diversos com casca não comestível, grandes            176.0
# 1                                                NaN              NaN
# 2  Produtos hortícolas cristalizados ou conservad...            293.0
# 3                   Frutos vegetais de cucurbitáceas             11.0
# 4                                       Peixe de mar             79.0
#
#    Energia (kJ)  Lípidos (g)  Ácidos gordos saturados (g)  ...  Cinza (g)  \
# 0         726.0         17.4                          4.2  ...       0.75
# 1           NaN          0.1                          NaN  ...        NaN
# 2        1240.0          0.2                          0.1  ...       0.15
# 3          47.0          0.2                          0.1  ...       0.40
# 4         334.0          0.1                          0.0  ...       2.00
#
#    Sódio (mg)  Potássio (mg)  Cálcio (mg)  Fósforo (mg)  Magnésio (mg)  \
# 0        15.0          330.0          4.0          36.0           21.0
# 1         NaN            NaN          NaN           NaN            NaN
# 2        27.0           22.0         28.0           2.0            3.0
# 3         1.0          200.0         25.0           5.0            5.0
# 4       360.0          360.0         13.0         270.0           36.0
#
#    Ferro (mg)  Zinco (mg)  Selénio (µg)  Iodo (µg)
# 0         0.3         0.3           NaN        NaN
# 1         NaN         NaN           NaN        NaN
# 2         0.4         0.1           NaN        NaN
# 3         0.1         0.1           NaN        NaN
# 4         0.2         0.6           NaN       22.0
#
# [5 rows x 48 columns]

# %%
# df1.dtypes

# %% [markdown]
# Equivalentes

# %%
df2 = pd.read_excel(input_path,engine='openpyxl',sheet_name='Equivalentes',usecols='A:P')
df2
# Out:
#           Grupo                       Nome  \
# 0        Outros                   Açúcares
# 1      Gorduras         Azeitona e Abacate
# 2    Hidratos I             Bebida de soja
# 3    Hidratos I             Bebida de soja
# 4    Hidratos I  Bebida vegetal sem açúcar
# ..          ...                        ...
# 357      Outros           Vinho ou Cerveja
# 358  Hidratos I     Leite e iogurte magros
# 359      Outros           Vinho ou Cerveja
# 360      Outros           Vinho ou Cerveja
# 361      Outros           Vinho ou Cerveja
#
#                                               Alimento  Porcao   Un Porcao  \
# 0                                       Açúcar amarelo      15      gramas
# 1                                             Azeitona      25      gramas
# 2    Bebida à base de soja com açúcar, com cálcio, ...     240      gramas
# 3    Bebida à base de soja natural, sem açúcar e se...     240      gramas
# 4                 Bebida à base de amêndoa, sem açúcar     240      gramas
# ..                                                 ...     ...         ...
# 357                                Vinho maduro branco     150  mililitros
# 358  Iogurte sem lactose líquido, magro, aromatizad...     180  mililitros
# 359                                     Cerveja branca     200  mililitros
# 360                                      Cerveja preta     200  mililitros
# 361                              Sidra (vinho de maçã)     250  mililitros
#
#     Media Plano  Qtd Medida Caseira Un Medida Caseira  \
# 0     Sim   Nao                 NaN               NaN
# 1     Sim   Nao                 NaN               NaN
# 2     Sim   Nao                 NaN               NaN
# 3     Nao   Nao                 NaN               NaN
# 4     Nao   Nao                 NaN               NaN
# ..    ...   ...                 ...               ...
# 357   Sim   Sim                 1.0             copos
# 358   Sim   Sim                 1.0          unidades
# 359   Sim   Sim                 1.0          unidades
# 360   Sim   Sim                 1.0          unidades
# 361   Sim   Sim                 1.0          unidades
#
#                                  Texto Medida Caseira  Hidratos  Lipidos  \
# 0                                                 NaN      97.5      0.0
# 1                                                 NaN       0.0     18.5
# 2                                                 NaN       4.2      2.1
# 3                                                 NaN       0.4      2.2
# 4                                                 NaN       0.1      1.1
# ..                                                ...       ...      ...
# 357                                de 150 ml de vinho       1.2      0.0
# 358  de iogurte liquido magro, sem adição de açucares       5.0      0.1
# 359                                   de cerveja mini       0.5      0.0
# 360                             de cerveja preta mini       0.6      0.0
# 361                               de garrafa de sidra       2.3      0.0
#
#      Proteinas  Alcool  Medida MacroCalculo
# 0          0.0     0.0      15     Hidratos
# 1          1.4     0.0       5      Lipidos
# 2          3.6     0.0      11     Hidratos
# 3          3.7     0.0       1     Hidratos
# 4          0.4     0.0       1     Hidratos
# ..         ...     ...     ...          ...
# 357        0.1     9.6      15       Alcool
# 358        3.3     0.0       9     Hidratos
# 359        0.4     3.7       8       Alcool
# 360        0.5     2.6       6       Alcool
# 361        0.0     5.5      14       Alcool
#
# [362 rows x 16 columns]

# %%
df2_filter = df2[df2['Media'] == 'Sim']
df2_filter
# Out:
#            Grupo                    Nome  \
# 0         Outros                Açúcares
# 1       Gorduras      Azeitona e Abacate
# 2     Hidratos I          Bebida de soja
# 5    Hidratos II                 Bolacha
# 6    Hidratos II                 Bolacha
# ..           ...                     ...
# 357       Outros        Vinho ou Cerveja
# 358   Hidratos I  Leite e iogurte magros
# 359       Outros        Vinho ou Cerveja
# 360       Outros        Vinho ou Cerveja
# 361       Outros        Vinho ou Cerveja
#
#                                               Alimento  Porcao   Un Porcao  \
# 0                                       Açúcar amarelo      15      gramas
# 1                                             Azeitona      25      gramas
# 2    Bebida à base de soja com açúcar, com cálcio, ...     240      gramas
# 5                                      Bolacha "Belga"      20      gramas
# 6                                        Bolacha aveia      20      gramas
# ..                                                 ...     ...         ...
# 357                                Vinho maduro branco     150  mililitros
# 358  Iogurte sem lactose líquido, magro, aromatizad...     180  mililitros
# 359                                     Cerveja branca     200  mililitros
# 360                                      Cerveja preta     200  mililitros
# 361                              Sidra (vinho de maçã)     250  mililitros
#
#     Media Plano  Qtd Medida Caseira Un Medida Caseira  \
# 0     Sim   Nao                 NaN               NaN
# 1     Sim   Nao                 NaN               NaN
# 2     Sim   Nao                 NaN               NaN
# 5     Sim   Nao                 NaN               NaN
# 6     Sim   Nao                 NaN               NaN
# ..    ...   ...                 ...               ...
# 357   Sim   Sim                 1.0             copos
# 358   Sim   Sim                 1.0          unidades
# 359   Sim   Sim                 1.0          unidades
# 360   Sim   Sim                 1.0          unidades
# 361   Sim   Sim                 1.0          unidades
#
#                                  Texto Medida Caseira  Hidratos  Lipidos  \
# 0                                                 NaN      97.5      0.0
# 1                                                 NaN       0.0     18.5
# 2                                                 NaN       4.2      2.1
# 5                                                 NaN      70.1     19.6
# 6                                                 NaN      57.5     18.3
# ..                                                ...       ...      ...
# 357                                de 150 ml de vinho       1.2      0.0
# 358  de iogurte liquido magro, sem adição de açucares       5.0      0.1
# 359                                   de cerveja mini       0.5      0.0
# 360                             de cerveja preta mini       0.6      0.0
# 361                               de garrafa de sidra       2.3      0.0
#
#      Proteinas  Alcool  Medida MacroCalculo
# 0          0.0     0.0      15     Hidratos
# 1          1.4     0.0       5      Lipidos
# 2          3.6     0.0      11     Hidratos
# 5          7.1     0.0      15     Hidratos
# 6         10.0     0.0      12     Hidratos
# ..         ...     ...     ...          ...
# 357        0.1     9.6      15       Alcool
# 358        3.3     0.0       9     Hidratos
# 359        0.4     3.7       8       Alcool
# 360        0.5     2.6       6       Alcool
# 361        0.0     5.5      14       Alcool
#
# [349 rows x 16 columns]

# %%
df3 = pd.merge(df2,df1,how='inner',left_on='Alimento',right_on='Nome do alimento')
df3['Energia (kcal)'] = df3['Lípidos (g)'] * 9 + df3['Hidratos de carbono (g)'] * 4 + df3['Proteínas (g)'] * 4 + df3['Álcool (g)'] * 7
df3['Hidratos (g) Porcao'] = df3['Hidratos de carbono (g)'] * df3['Porcao'] / 100
df3['Lípidos (g) Porcao'] = df3['Lípidos (g)'] * df3['Porcao'] / 100
df3['Proteínas (g) Porcao'] = df3['Proteínas (g)'] * df3['Porcao'] / 100
df3['Álcool (g) Porcao'] = df3['Álcool (g)'] * df3['Porcao'] / 100
df3_grouped = df3.groupby(by=['Grupo','Nome'])[['Porcao','Lípidos (g) Porcao','Hidratos (g) Porcao','Proteínas (g) Porcao','Álcool (g) Porcao']].mean()
df3_grouped.reset_index(inplace=True)
df3_rounded = df3_grouped.round(decimals={
                    'Porcao':0,
                    'Lípidos (g) Porcao':1,
                    'Hidratos (g) Porcao':1,
                    'Proteínas (g) Porcao':1,
                    'Álcool (g) Porcao':1
                    })
df3_rounded
# Out:
#           Grupo                       Nome  Porcao  Lípidos (g) Porcao  \
# 0      Gorduras         Azeitona e Abacate    25.0                 4.5
# 1      Gorduras              Frutos Gordos    10.0                 5.9
# 2      Gorduras           Gorduras e óleos     5.0                 4.7
# 3      Gorduras  Manteiga de frutos gordos    10.0                 5.0
# 4      Gorduras    Manteiga e cremes light    10.0                 4.3
# 5    Hidratos I             Bebida de soja   240.0                 5.2
# 6    Hidratos I  Bebida vegetal sem açúcar   240.0                 2.6
# 7    Hidratos I               Fruta (100g)   100.0                 0.3
# 8    Hidratos I               Fruta (200g)   170.0                 0.7
# 9    Hidratos I                Fruta (50g)    47.0                 0.2
# 10   Hidratos I  Iogurtes proteicos magros   138.0                 0.2
# 11   Hidratos I             Legumes (100g)   100.0                 0.5
# 12   Hidratos I    Legumes (consumo livre)   100.0                 0.4
# 13   Hidratos I                Leite Gordo   240.0                 8.3
# 14   Hidratos I         Leite e iogurte MG   244.0                 3.9
# 15   Hidratos I     Leite e iogurte magros   239.0                 1.0
# 16   Hidratos I                  Queijo MG    40.0                 7.9
# 17   Hidratos I               Queijo magro    37.0                 2.3
# 18   Hidratos I                       Sopa   250.0                 3.2
# 19  Hidratos II                    Bolacha    20.0                 3.1
# 20  Hidratos II  Bolacha de Milho ou Arroz    20.0                 0.6
# 21  Hidratos II          Cereais e granola    22.0                 0.6
# 22  Hidratos II                  Guarnição    68.0                 0.6
# 23  Hidratos II                        Pão    27.0                 0.7
# 24  Leguminosas                Leguminosas    75.0                 0.7
# 25       Outros                   Açúcares    15.0                 0.0
# 26       Outros                     Claras    55.0                 0.1
# 27       Outros                   Compotas     5.0                 0.0
# 28       Outros                   Farinhas    20.0                 0.5
# 29       Outros          Fruta desidratada    15.0                 0.3
# 30       Outros           Vinho ou Cerveja   172.0                 0.0
# 31    Proteínas              Carne e Peixe    30.0                 1.6
# 32    Proteínas            Fiambre de aves    50.0                 1.2
# 33    Proteínas                       Ovos    60.0                 6.2
# 34    Proteínas              Peixes gordos    30.0                 3.7
# 35    Proteínas                       Soja    50.0                 3.8
# 36    Proteínas                       Tofu    60.0                 2.6
# 37    Proteínas    Whey e proteína vegetal    30.0                 1.4
#
#     Hidratos (g) Porcao  Proteínas (g) Porcao  Álcool (g) Porcao
# 0                   0.3                   0.3                0.0
# 1                   0.8                   1.9                0.0
# 2                   0.0                   0.0                0.0
# 3                   0.7                   3.0                0.0
# 4                   0.1                   0.1                0.0
# 5                   8.8                   8.9                0.0
# 6                   0.2                   1.0                0.0
# 7                   9.9                   0.7                0.0
# 8                  10.1                   1.2                0.0
# 9                   9.3                   0.3                0.0
# 10                  9.8                  13.2                0.0
# 11                  3.4                   2.0                0.0
# 12                  1.2                   1.9                0.0
# 13                 11.3                   7.3                0.0
# 14                 12.0                   8.6                0.0
# 15                 11.8                   9.9                0.0
# 16                  0.8                   7.2                0.0
# 17                  1.6                   7.1                0.0
# 18                 11.9                   3.0                0.0
# 19                 13.0                   1.8                0.0
# 20                 16.4                   1.6                0.0
# 21                 14.4                   2.4                0.0
# 22                 15.5                   2.0                0.0
# 23                 14.6                   2.5                0.0
# 24                  9.4                   6.3                0.0
# 25                 14.8                   0.0                0.0
# 26                  0.3                   5.9                0.0
# 27                  2.8                   0.0                0.0
# 28                 14.2                   1.9                0.0
# 29                  9.1                   0.6                0.0
# 30                  1.6                   0.3               11.8
# 31                  0.0                   7.3                0.0
# 32                  1.2                   7.1                0.0
# 33                  0.0                   7.6                0.0
# 34                  0.0                   6.9                0.0
# 35                  2.8                   6.2                0.0
# 36                  0.4                   5.1                0.0
# 37                  1.1                  25.1                0.0

# %%
df4 = pd.merge(df2_filter,df1,how='inner',left_on='Alimento',right_on='Nome do alimento')
df4['Energia (kcal)'] = df4['Lípidos (g)'] * 9 + df4['Hidratos de carbono (g)'] * 4 + df4['Proteínas (g)'] * 4 + df4['Álcool (g)'] * 7
df4['Hidratos (g) Porcao'] = df4['Hidratos de carbono (g)'] * df4['Porcao'] / 100
df4['Lípidos (g) Porcao'] = df4['Lípidos (g)'] * df4['Porcao'] / 100
df4['Proteínas (g) Porcao'] = df4['Proteínas (g)'] * df4['Porcao'] / 100
df4['Álcool (g) Porcao'] = df4['Álcool (g)'] * df4['Porcao'] / 100
df5 = df4.groupby(by=['Grupo'])[['Porcao','Lípidos (g) Porcao','Hidratos (g) Porcao','Proteínas (g) Porcao','Álcool (g) Porcao']].mean()
df6 = df5.round(decimals={
                    'Porcao':0,
                    'Lípidos (g) Porcao':1,
                    'Hidratos (g) Porcao':1,
                    'Proteínas (g) Porcao':1,
                    'Álcool (g) Porcao':1
                    })
df6.reset_index(inplace=True)
df6
# Out:
#          Grupo  Porcao  Lípidos (g) Porcao  Hidratos (g) Porcao  \
# 0     Gorduras    10.0                 5.3                  0.5
# 1   Hidratos I   145.0                 1.5                  7.4
# 2  Hidratos II    30.0                 1.2                 14.5
# 3  Leguminosas    75.0                 0.7                  9.4
# 4       Outros    47.0                 0.2                  8.0
# 5    Proteínas    33.0                 2.1                  0.2
#
#    Proteínas (g) Porcao  Álcool (g) Porcao
# 0                   1.1                0.0
# 1                   3.1                0.0
# 2                   2.2                0.0
# 3                   6.3                0.0
# 4                   1.0                2.3
# 5                   8.0                0.0

# %%
df7 = df2[df2['Plano'] == 'Sim']
df7_clean = df7.drop(columns=['Media','Plano'])
df7_clean
# Out:
#            Grupo                    Nome  \
# 252  Hidratos II                 Bolacha
# 253  Hidratos II                 Bolacha
# 254  Hidratos II                 Bolacha
# 255  Hidratos II                 Bolacha
# 256  Hidratos II                 Bolacha
# ..           ...                     ...
# 357       Outros        Vinho ou Cerveja
# 358   Hidratos I  Leite e iogurte magros
# 359       Outros        Vinho ou Cerveja
# 360       Outros        Vinho ou Cerveja
# 361       Outros        Vinho ou Cerveja
#
#                                               Alimento  Porcao   Un Porcao  \
# 252                           Bolacha integral (trigo)      20      gramas
# 253                            Bolacha "Cream cracker"      20      gramas
# 254                                      Bolacha Maria      20      gramas
# 255                                        Marinheiras      20      gramas
# 256                                 Bolacha água e sal      20      gramas
# ..                                                 ...     ...         ...
# 357                                Vinho maduro branco     150  mililitros
# 358  Iogurte sem lactose líquido, magro, aromatizad...     180  mililitros
# 359                                     Cerveja branca     200  mililitros
# 360                                      Cerveja preta     200  mililitros
# 361                              Sidra (vinho de maçã)     250  mililitros
#
#      Qtd Medida Caseira Un Medida Caseira  \
# 252                 3.0          bolachas
# 253                 4.0          bolachas
# 254                 4.0          bolachas
# 255                 4.0          bolachas
# 256                 8.0          bolachas
# ..                  ...               ...
# 357                 1.0             copos
# 358                 1.0          unidades
# 359                 1.0          unidades
# 360                 1.0          unidades
# 361                 1.0          unidades
#
#                                  Texto Medida Caseira  Hidratos  Lipidos  \
# 252                                 de trigo integral      65.6     15.6
# 253                                          bolachas      61.6     16.2
# 254                                             maria      72.0     12.2
# 255                                       marinheiras      64.0     11.8
# 256                            de água e sal redondas      61.0     17.8
# ..                                                ...       ...      ...
# 357                                de 150 ml de vinho       1.2      0.0
# 358  de iogurte liquido magro, sem adição de açucares       5.0      0.1
# 359                                   de cerveja mini       0.5      0.0
# 360                             de cerveja preta mini       0.6      0.0
# 361                               de garrafa de sidra       2.3      0.0
#
#      Proteinas  Alcool  Medida MacroCalculo
# 252        8.8     0.0      14     Hidratos
# 253       10.8     0.0      13     Hidratos
# 254        8.4     0.0      15     Hidratos
# 255       11.8     0.0      13     Hidratos
# 256        9.8     0.0      13     Hidratos
# ..         ...     ...     ...          ...
# 357        0.1     9.6      15       Alcool
# 358        3.3     0.0       9     Hidratos
# 359        0.4     3.7       8       Alcool
# 360        0.5     2.6       6       Alcool
# 361        0.0     5.5      14       Alcool
#
# [108 rows x 14 columns]

# %%
df1.to_json(output_path_tca,orient='records')
df2.to_json(output_path_equivalentes_detalhe,orient='records')
df3.to_json(output_path_equivalentes,orient='records')
df3_rounded.to_csv(output_path_equivalentes_csv,sep=',',decimal='.',encoding='utf-8')
df6.to_csv(output_path_equivalentes_resumo_csv,sep=',',decimal='.',encoding='utf-8')
df7_clean.to_csv(output_path_equivalentes_detalhe_csv,sep=',',decimal='.',encoding='utf-8')

# %% [markdown]
# # THE END
